# %% [markdown]
# #  List of APP to install on windows

# %% [markdown]
# [GIT](https://www.google.com/search?q=download+git&oq=download+git+&aqs=chrome.0.69i59j0l6j69i60.2927j0j1&sourceid=chrome&ie=UTF-8)
#
# [Utorrent](https://www.utorrent.com/desktop) remove ad [from utorrent](https://lifehacker.com/disable-ads-in-utorrent-via-settings-826283231)
#
# [Anaconda](https://www.anaconda.com/products/individual)
#
# [BlueStacks](https://www.bluestacks.com/download.html)
#
# [AnyDesk](https://anydesk.com/en/downloads/windows)
#
# [Everything](https://www.voidtools.com/downloads/)
#
# [KMPlayer 64X](https://www.kmplayer.com/pc64x)
#
# [QTranslate](https://quest-app.appspot.com/download)
#
# [Speccy](https://soft98.ir/software/753-Speccy.html)
#
# [TreeSize](https://soft98.ir/software/753-Speccy.html)
#
# [VLC media player](https://www.videolan.org/vlc/)
#
# [Internet Download Manager](https://soft98.ir/internet/download-manager/4-idm-fulll-dl.html)
#
# [Unfx Proxy Checker](https://www.electronjs.org/apps/unfx-proxy-checker)
#
# [TweakPower ](https://kurtzimmermann.com/index_e.html)
#
# Notepad++
#
#
# **to block each app from access to internet use block.bat file in my nootbook folder**

# %% [markdown]
# pin this app to start :
# ThisPc
# Everythings
# Google chrome
# mozila firefox
# IDM
# eve

# %% [markdown]
# # App settings  on windows

# %% [markdown]
# **foxit phantomPDF** :
#
# file> Preferences > Replace document colors > coustom color >page background (238,238,238)
# right click on toolbar > Customiz qouick acsees toolbar >keyboard :
#
# category home  > hand  > 4
#
# category home  > select text and image   > 1
#
# category comment  > Highlight > 2
#
#
# click on home toolbar > highligt > then clekc on comment foramt > right click on gallery color > add Gallery to quick access tollbar

# %% [markdown]
# **Mendeley**
#
#
#
# **Telegram**
# change the download path to
# settings > Advence > Download path >  G:\Downloads\telgram

# %% [markdown]
# ## Microsoft

# %% [markdown]
# ### **WORD**

# %% [markdown]
# there are couple of word Micro that can be useful for document code and sample task
#
# **[show developer tab](https://support.microsoft.com/en-us/topic/show-the-developer-tab-e1192344-5e56-4d45-931b-e5fd9bea2d45)**

# %% [markdown]
# #### insert code insde word like IDE format

# %% [markdown]
# **insert code insde word like IDE format**
#
# see this [link](https://stackoverflow.com/questions/387453/how-do-you-display-code-snippets-in-ms-word-preserving-format-and-syntax-highlig) and made macro base on this solution.
#
# macro code it is like this:
# ```
# Sub insert_code_with_format()
# '
# ' insert_code_with_format Macro
# '
# '
#     Selection.InlineShapes.AddOLEObject ClassType:="Word.OpenDocumentText.12", _
#          FileName:="", LinkToFile:=False, DisplayAsIcon:=False
#     Selection.Paste
#     ActiveDocument.SaveAs2 FileName:= _
#         "C:\Users\zana\AppData\Local\Microsoft\Windows\INetCache\Content.Word\~WRO1103.doc" _
#         , FileFormat:=wdFormatXMLDocument, LockComments:=False, Password:="", _
#         AddToRecentFiles:=True, WritePassword:="", ReadOnlyRecommended:=False, _
#         EmbedTrueTypeFonts:=False, SaveNativePictureFormat:=False, SaveFormsData _
#         :=False, SaveAsAOCELetter:=False, CompatibilityMode:=15
#     ActiveWindow.Close
# End Sub
#
#
# ```

# %% [markdown]
# # Ubuntu

# %% [markdown]
# Install elastic search ---> https://phoenixnap.com/kb/install-elasticsearch-ubuntu
#
#
# fix share clipboard problem in virturalbox
# https://docs.bitnami.com/virtual-machine/faq/configuration/install-virtualbox-guest-additions/

# %% [markdown]
# # Chrome Extention

# %% [markdown]
# [Agenty - Advanced Web Scraper](https://chrome.google.com/webstore/detail/agenty-advanced-web-scrap/gpolcofcjjiooogejfbaamdgmgfehgff)
#
#
# [Autofill](https://chrome.google.com/webstore/detail/autofill/nlmmgnhgdeffjkdckmikfpnddkbbfkkk)
#
#
# [chatrbaazan](https://chrome.google.com/webstore/detail/chatrbaazan/dmmhllbcildldllginbbfbbnnilgjeff)
#
#
# [Checker Plus for Google Calendar™](https://chrome.google.com/webstore/detail/checker-plus-for-google-c/hkhggnncdpfibdhinjiegagmopldibha)
#
#
# [Chrome Remote Desktop](https://chrome.google.com/webstore/detail/chrome-remote-desktop/inomeogfingihgjfjlpeplalcfajhgai)
#
#
# [Context Menu Search](https://chrome.google.com/webstore/detail/context-menu-search/ocpcmghnefmdhljkoiapafejjohldoga)
#
#
# [WakaTime](https://chrome.google.com/webstore/detail/wakatime/jnbbnacmeggbgdjgaoojpmhdlkkpblgi)
#
#
# [Tampermonkey](https://chrome.google.com/webstore/detail/tampermonkey/dhdgffkkebhmkfjojejmpbldmpobfkfo)
#
#
# [Chrono Download Manager](https://chrome.google.com/webstore/detail/chrono-download-manager/mciiogijehkdemklbdcbfkefimifhecn)
#
#
# [Clockify Time Tracker](https://chrome.google.com/webstore/detail/clockify-time-tracker/pmjeegjhjdlccodhacdgbgfagbpmccpe)
#
#
# [Edit Anything](https://chrome.google.com/webstore/detail/edit-anything/kgkhambjbahgejgoaefmekdchedkihln)
#
# [Easy Auto Refresh](https://chrome.google.com/webstore/detail/easy-auto-refresh/aabcgdmkeabbnleenpncegpcngjpnjkc)
#
# [Download by Internet Download Manager](https://chrome.google.com/webstore/detail/download-by-internet-down/lgbipmmmnjifkiiikaffhceflifbmhib)
#
#
# []()
#
# []()
#
# []()
#
# []()
#
# []()
#
# []()
#
# []()
#
# []()

# %% [markdown]
# [Evernote Web Clipper
# ](https://chrome.google.com/webstore/detail/evernote-web-clipper/pioclpoplcdbaefihamjohnefbikjilc)
# [Foxit PDF Creator
# ](https://chrome.google.com/webstore/detail/foxit-pdf-creator/cifnddnffldieaamihfkhkdgnbhfmaci)
#
# [Free Download Manager
# ](https://chrome.google.com/webstore/detail/free-download-manager/ahmpjcflkgiildlgicmcieglgoilbfdp)
#
# [Honey](https://chrome.google.com/webstore/detail/honey/bmnlcjabgnpnenekpadlanbbkooimhnj)
#
# [Helium 10
# ](https://chrome.google.com/webstore/detail/helium-10/njmehopjdpcckochcggncklnlmikcbnb)
#
# [IE Tab
# ](https://chrome.google.com/webstore/detail/ie-tab/hehijbfgiekmjfkfjpbkbammjbdenadd)
#
# [Iranian Lifetime Calculator
# ](https://chrome.google.com/webstore/detail/iranian-lifetime-calculat/phoehnanhimojcbebjldknajipijlmhd)
#
# []()

# %% [markdown]
# [EditThisCookie
# ](https://chrome.google.com/webstore/detail/editthiscookie/fngmhnnpilhplaeedifhccceomclgfbg)
#
# [EndNote Click - Formerly Kopernio
# ](https://chrome.google.com/webstore/detail/endnote-click-formerly-ko/fjgncogppolhfdpijihbpfmeohpaadpc)
#
# [Open With Internet Download Manager
# ](https://chrome.google.com/webstore/detail/open-with-internet-downlo/epgilldoipfbdlneomlmegekaoonchcj)
#
# [Cool Clock
# ](https://chrome.google.com/webstore/detail/cool-clock/icegcmhgphfkgglbljbkdegiaaihifce)
#
# [Dark Reader
# ](https://chrome.google.com/webstore/detail/dark-reader/eimadpbcbfnmbkopoojfekhnkhdbieeh)
#
# [Office
# ](https://chrome.google.com/webstore/detail/office/ndjpnladcallmjemlbaebfadecfhkepb)
#
# [Phantombuster
# ](https://chrome.google.com/webstore/detail/phantombuster/mdlnjfcpdiaclglfbdkbleiamdafilil)
#
# [PDF Viewer
# ](https://chrome.google.com/webstore/detail/pdf-viewer/oemmndcbldboiebfnladdacbdfmadadm)
#
# [Todoist for Chrome
# ](https://chrome.google.com/webstore/detail/todoist-for-chrome/jldhpllghnbhlbpcmnajkpdmadaolakh)
#
# [StayFocusd
# ](https://chrome.google.com/webstore/detail/stayfocusd/laankejkbhbdhmipfmgcngdelahlfoji)
#
# [Project Naptha
# ](https://chrome.google.com/webstore/detail/project-naptha/molncoemjfmpgdkbdlbjmhlcgniigdnf)
#
# [Notion Web Clipper
# ](https://chrome.google.com/webstore/detail/notion-web-clipper/knheggckgoiihginacbkhaalnibhilkk)
#
# [Nimbus Screenshot & Screen Video Recorder
# ](https://chrome.google.com/webstore/detail/nimbus-screenshot-screen/bpconcjcammlapcogcnnelfmaeghhagj)
#
# [Hypothesis - Web & PDF Annotation
# ](https://chrome.google.com/webstore/detail/hypothesis-web-pdf-annota/bjfhmglciegochdpefhhlphglcehbmek)
#
# [Google Dictionary (by Google)
# ](https://chrome.google.com/webstore/detail/google-dictionary-by-goog/mgijmajocgfcbeboacabfgobmjgjcoja)
#
# [Google Input Tools
# ](https://chrome.google.com/webstore/detail/google-input-tools/mclkkofklkfljcocdinagocijmpgbhab)
#
# [Cashineh خرید اینترنتی با
# ](https://chrome.google.com/webstore/detail/cashineh-%D8%AE%D8%B1%DB%8C%D8%AF-%D8%A7%DB%8C%D9%86%D8%AA%D8%B1%D9%86%D8%AA%DB%8C-%D8%A8%D8%A7/cckmldjgbpncchpicjgkhomffokcodpl)
#
# []()
#
# []()
