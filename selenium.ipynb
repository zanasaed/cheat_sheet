# %% [markdown]
# # selenium cheat sheet and important stack or website

# %% [markdown]
# Exceptions – Selenium Python
# for handeling exceptions gor to this [toturial](https://www.geeksforgeeks.org/exceptions-selenium-python/)
