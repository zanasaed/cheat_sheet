# %% [markdown]
# # Work directory

# %% [markdown]
# If you want import other python file to another file the path of that file must be in python path so we need before import a file first add thier path to python path there is a couple senario
#
# 1.   if file is in the diffrent folder add the folder path to python path like this
#
#
#
# ```
# import sys
# sys.path.append('F:\\code\\work_project\\DIGIKALA\\Utility')
#
# from  Utility import DatabaseHelper , util
#
# ```
#
#
# 2.   List item

# %% [markdown]
# ## See work Directory
#
#
# ```
#     cwd = os.getcwd()
#     # Print the current working directory
#     print("Current working directory: {0}".format(cwd))
#
#     # Print the type of the returned object
#     print("os.getcwd() returns an object of type: {0}".format(type(cwd)))
#
# ```
# **How to Get and Change the Current Working Directory in Python**
# https://linuxize.com/post/python-get-change-current-working-directory/#:~:text=To%20find%20the%20current%20working,chdir(path)%20.

# %% [markdown]
# # **Time**

# %%
import datetime
now = datetime.datetime.now()
print(f'another epoch  {now.strftime("%Y-%m-%d %H:%M:%S")}', end='\r')

# %% [markdown]
# # Library for installing

# %%
import tkinter
https://anaconda.org/anaconda/tk

import shutil
https://anaconda.org/conda-forge/pytest-shutil

import re 
https://anaconda.org/conda-forge/regex

import pyautogui
https://anaconda.org/conda-forge/pyautogui

from PIL import Image, ImageGrab
https://anaconda.org/anaconda/pillow

from mss import mss
https://anaconda.org/conda-forge/mss

import time

import cv2
https://anaconda.org/conda-forge/opencv

import mouse
pip install mouse

import keyboard
pip install keyboard


import requests
https://anaconda.org/anaconda/requests

import io



import pymongo
https://anaconda.org/anaconda/pymongo

### For work on web crawling  ###
import scrapy
https://anaconda.org/conda-forge/scrapy


import selenium
https://anaconda.org/conda-forge/selenium

from rotating_proxies.policy import BanDetectionPolicy
https://pypi.org/project/scrapy-rotating-proxies/

from fake_useragent import UserAgent
https://pypi.org/project/fake-useragent/

from itemloaders.processors import TakeFirst
https://anaconda.org/conda-forge/itemloaders

# %% [markdown]
# **Update all packages in anaconda envirment**
#
#
# ```
# conda update --all
# ```
